# %% [markdown]
# <a href="https://colab.research.google.com/github/wiv33/A-Learning-python/blob/master/machine-learning/_000_hello_machine/_000_basic/_003_cuk_edu/_005_3_computer_vision/10_neural_style_transfer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 16336255407971244434
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 5726273536
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 12624592753053922490
#  physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3080 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6"
#  xla_global_id: 416903419]

# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
print(gpus)
if gpus:
  # 텐서플로가 첫 번째 GPU만 사용하도록 제한
  try:
    tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
  except RuntimeError as e:
    # 프로그램 시작시에 접근 가능한 장치가 설정되어야만 합니다
    print(e)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Inside the conv layer

# %% [markdown]
# **Conv filter 시각화**

# %%
# summarize filters in each convolutional layer
from tensorflow.keras.applications.vgg16 import VGG16
from matplotlib import pyplot

# load the model
model = VGG16()
model.summary()
# summarize filter shapes
for layer in model.layers:
    # check for convolutional layer
    if 'conv' not in layer.name:
        continue
    # get filter weights
    filters, biases = layer.get_weights()
    print(layer.name, filters.shape)

# retrieve weights from the first hidden layer
layer_num = 2
filters, biases = model.layers[layer_num].get_weights()
print(model.layers[layer_num].name)

# normalize filter values to 0-1 so we can visualize them
f_min, f_max = filters.min(), filters.max()
filters = (filters - f_min) / (f_max - f_min)

# plot first few filters
n_filters, ix = 6, 1
for i in range(n_filters):
    # get the filter
    f = filters[:, :, :, i]
    # plot each channel separately
    for j in range(3): # RGB
        # specify subplot and turn of axis
        ax = pyplot.subplot(n_filters, 3, ix)
        ax.set_xticks([])
        ax.set_yticks([])
        # plot filter channel in grayscale
        pyplot.imshow(f[:, :, j], cmap='gray')
        ix += 1
# show the figure
pyplot.show()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________
# block1_conv1 (3, 3, 3, 64)
# block1_conv2 (3, 3, 64, 64)
# block2_conv1 (3, 3, 64, 128)
# block2_conv2 (3, 3, 128, 128)
# block3_conv1 (3, 3, 128, 256)
# block3_conv2 (3, 3, 256, 256)
# block3_conv3 (3, 3, 256, 256)
# block4_conv1 (3, 3, 256, 512)
# block4_conv2 (3, 3, 512, 512)
# block4_conv3 (3, 3, 512, 512)
# block5_conv1 (3, 3, 512, 512)
# block5_conv2 (3, 3, 512, 512)
# block5_conv3 (3, 3, 512, 512)
# block1_conv2

# %%
from matplotlib import image as mp_image
import matplotlib.pyplot as plt
from tensorflow import keras

url = 'https://raw.githubusercontent.com/kotech1/computervision/master/img/2011_002300-dog.jpg'

sample_image_path = keras.utils.get_file(
    "2011_002300-dog.jpg", url
)
image = mp_image.imread(sample_image_path)
plt.imshow(image)
plt.show()
# Out:
# Downloading data from https://raw.githubusercontent.com/kotech1/computervision/master/img/2011_002300-dog.jpg
# 175582/175582 [==============================] - 0s 0us/step

# %% [markdown]
# **Activation value 시각화**

# %%
# plot feature map of first conv layer for given image
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
from numpy import expand_dims

# load the model
model = VGG16()

layer = 17  # 1 to 17
# redefine model to output right after the first hidden layer
model = Model(inputs=model.inputs, outputs=model.layers[layer].output)
# load the image with the required shape
#img = load_img('bird.jpg', target_size=(224, 224))
img = load_img(sample_image_path, target_size=(224, 224))
# convert the image to an array
img = img_to_array(img)
# expand dimensions so that it represents a single 'sample'
img = expand_dims(img, axis=0)
# prepare the image (e.g. scale pixel values for the vgg)
img = preprocess_input(img)
# get feature map for first hidden layer
feature_maps = model.predict(img)
# plot all 64 maps in an 8x8 squares
square = 8
ix = 1
offset = 0 # 0, 64, 128 ... 
plt.figure(figsize=(8,10))
for _ in range(square):
    for _ in range(square):
        # specify subplot and turn of axis
        ax = plt.subplot(square, square, ix)
        ax.set_xticks([])
        ax.set_yticks([])
        # plot filter channel in grayscale
        #plt.imshow(feature_maps[0, :, :, ix-1+offset], cmap='gray')
        img = feature_maps[0, :, :, ix-1+offset]
        import numpy as np
        img = np.clip(img, -1000, 1000)
        #plt.imshow(feature_maps[0, :, :, ix-1+offset])
        plt.imshow(img)
        ix += 1
# show the figure
plt.show()
# Out:
# 1/1 [==============================] - 0s 180ms/step

# %% [markdown]
# # Neural Style Transfer

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import vgg19

# %% [markdown]
# **손실함수 scale factors**

# %%
# Weights of the different loss components
total_variation_weight = 1e-6
style_weight = 1e-6
content_weight = 2.5e-8

total_variation_weight = 5e-7
style_weight = 1e-5
content_weight = 2.5e-8

#
#total_variation_weight = 1e-8
#style_weight = 5e-5 #generated6
#content_weight = 1e-10

# %% [markdown]
# C: base_image
# S: style_reference_image
# G: combined_image

# %%
base_image_path = keras.utils.get_file(
    "london-bridge.jpg", "https://pixy.org/src/0/thumbs350/123.jpg"
)
style_reference_image_path = keras.utils.get_file(
    "franz-marc.jpg", "https://upload.wikimedia.org/wikipedia/commons/thumb/7/7c/Les_Premiers_animaux_de_Franz_Marc_%28Mus%C3%A9e_de_l%27Orangerie%2C_Paris%29_%2840833051033%29.jpg/691px-Les_Premiers_animaux_de_Franz_Marc_%28Mus%C3%A9e_de_l%27Orangerie%2C_Paris%29_%2840833051033%29.jpg"
)
result_prefix = 'london_generated'
# Out:
# Downloading data from https://pixy.org/src/0/thumbs350/123.jpg
# 130710/130710 [==============================] - 1s 6us/step
# Downloading data from https://upload.wikimedia.org/wikipedia/commons/thumb/7/7c/Les_Premiers_animaux_de_Franz_Marc_%28Mus%C3%A9e_de_l%27Orangerie%2C_Paris%29_%2840833051033%29.jpg/691px-Les_Premiers_animaux_de_Franz_Marc_%28Mus%C3%A9e_de_l%27Orangerie%2C_Paris%29_%2840833051033%29.jpg
# 117408/117408 [==============================] - 0s 2us/step

# %%
from matplotlib import image as mp_image
import matplotlib.pyplot as plt
img = mp_image.imread(base_image_path)
plt.imshow(img)
plt.show()

img = mp_image.imread(style_reference_image_path)
plt.imshow(img)
plt.show()

# %% [markdown]
# 세로 방향을 400px로, aspect ratio를 유지하며 출력 이미지 크기 정의

# %%
# Dimensions of the generated picture.
width, height = keras.preprocessing.image.load_img(base_image_path).size
img_nrows = 800
img_ncols = int(width * img_nrows / height)

# %% [markdown]
# VGG19의 image level normalization, de-normalization

# %%
def preprocess_image(image_path):
    # Util function to open, resize and format pictures into appropriate tensors
    img = keras.preprocessing.image.load_img(
        image_path, target_size=(img_nrows, img_ncols)
    )
    img = keras.preprocessing.image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return tf.convert_to_tensor(img)


def deprocess_image(x):
    # Util function to convert a tensor into a valid image
    x = x.reshape((img_nrows, img_ncols, 3))
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype("uint8")
    return x

# %% [markdown]
# **Gram matrix**

# %%
# 이미지 텐서의 gram matrix (특징별 outer product)

def gram_matrix(x):
    # 채널을 맨 앞으로, w,h를 뒤로 보냄
    x = tf.transpose(x, (2, 0, 1)) 
    # (c, h, w) ==> (c, w*h)
    features = tf.reshape(x, (tf.shape(x)[0], -1)) 
    # (c, w*h) x (w*h,c) = (c,c) 
    gram = tf.matmul(features, tf.transpose(features))  
    return gram

# %% [markdown]
# **Style Loss**

# %%
# style loss는 reference image와 generated image간의 
# 스타일 차이를 유지할 수 있도록 하는 역할을 한다.
# gram matrix의 차이의 squared error로 정의

def style_loss(style, combination):
    S = gram_matrix(style)
    C = gram_matrix(combination)
    # 논문의 정확한 implementation은 다음과 같아야 함
    # channels = style.shape[2]
    # size = style.shape[0] * style.shape[1] 
    channels = 3
    size = img_nrows * img_ncols
    return tf.reduce_sum(tf.square(S - C)) / (4.0 * (channels ** 2) * (size ** 2))

# %% [markdown]
# **Content Loss**

# %%
# 콘텐츠 손실 함수
# 생성된 이미지에서 base 이미지의 "content"를
# 유지하기 위함

def content_loss(base, combination):
    return tf.reduce_sum(tf.square(combination - base))

# %% [markdown]
# **Total variation loss**

# %%
# 3번째 손실함수: total variation loss
# designed to keep the generated image locally coherent

def total_variation_loss(x):
    a = tf.square(
        x[:, : img_nrows - 1, : img_ncols - 1, :] - x[:, 1:, : img_ncols - 1, :]
    )
    b = tf.square(
        x[:, : img_nrows - 1, : img_ncols - 1, :] - x[:, : img_nrows - 1, 1:, :]
    )
    return tf.reduce_sum(tf.pow(a + b, 1.25))

# %% [markdown]
# **VGG19**

# %%
# VGG19 model 로딩 (pre-trained ImageNet weights)
model = vgg19.VGG19(weights="imagenet", include_top=False)
model.summary()

# 모델에서 레이어 이름과 레이어 출력 형식을 가져옴
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])

# VGG 모델의 전체 activation value를 출력하는 함수 정의
# (dict 형식)
feature_extractor = keras.Model(inputs=model.inputs, outputs=outputs_dict)
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv4 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
# style loss에 사용할 레이어
#style_layer_names = [
#    "block1_conv1",
#    "block2_conv1",
#    "block3_conv1",
#    "block4_conv1",
#    "block5_conv1",
#]

style_layer_names = [
    "block1_conv2",
    "block2_conv2",
    "block3_conv2",
    "block4_conv2",
    "block5_conv2",
]

# content loss에 사용할 레이어
content_layer_name = "block5_conv2"

def compute_loss(combination_image, base_image, style_reference_image):
    input_tensor = tf.concat(
        [base_image, style_reference_image, combination_image], axis=0
    )
    features = feature_extractor(input_tensor)

    # loss 초기화
    loss = tf.zeros(shape=())

    # content loss
    layer_features = features[content_layer_name]
    base_image_features = layer_features[0, :, :, :]
    combination_features = layer_features[2, :, :, :]
    c_loss = content_weight * content_loss(
        base_image_features, combination_features
    )
    s_loss = tf.zeros(shape=())
    # Add style loss
    for layer_name in style_layer_names:
        layer_features = features[layer_name]
        style_reference_features = layer_features[1, :, :, :]
        combination_features = layer_features[2, :, :, :]
        sl = style_loss(style_reference_features, combination_features)
        s_loss += (style_weight / len(style_layer_names)) * sl
    
    # total variation loss
    t_loss = total_variation_weight * total_variation_loss(combination_image)
    loss = c_loss+s_loss+t_loss 
    return loss, c_loss, s_loss, t_loss

# %%
# 여러 복잡한 연산 실행히 빠른 실행을 위한 사전 컴파일
@tf.function
def compute_loss_and_grads(combination_image, base_image, style_reference_image):
    # 안에서 일어나는 연산을 gradient를 추적할 수 있음.
    # loss를 계산할 때는 gradientTape 안에서 계산해야함.
    with tf.GradientTape() as tape:
        loss, c_loss, s_loss, t_loss = compute_loss(combination_image, base_image, style_reference_image)
    grads = tape.gradient(loss, combination_image)
    return loss, grads, c_loss, s_loss, t_loss

# %% [markdown]
# **다음의 학습 코드를 수행하는 데에는 약3시간 정도 소요됩니다.**

# %%
optimizer = keras.optimizers.SGD(
    keras.optimizers.schedules.ExponentialDecay( # 트레이닝이 길어질 때 learning rate를 점점 줄여주도록 하는 deco
        initial_learning_rate=100.0, decay_steps=100, decay_rate=0.96
    )
)

base_image = preprocess_image(base_image_path)
style_reference_image = preprocess_image(style_reference_image_path)
combination_image = tf.Variable(preprocess_image(base_image_path))

iterations = 1200
for i in range(1, iterations + 1):
    loss, grads, c_loss, s_loss, t_loss = compute_loss_and_grads(
        combination_image, base_image, style_reference_image
    )
    optimizer.apply_gradients([(grads, combination_image)])
    if i % 10 == 0 or i == 1:
        print("Iteration %d: loss=%.2f, content_loss=%.2f, style_loss=%.2f, total_variation_loss=%.2f" %
               (i, loss, c_loss, s_loss, t_loss))
    if i % 100 == 0:
        img = deprocess_image(combination_image.numpy())
        fname = result_prefix + "_at_iteration_%d.png" % i
        keras.preprocessing.image.save_img(fname, img)

# %%
img = mp_image.imread(result_prefix + '_at_iteration_'+'%d.png' % 1300)
plt.imshow(img)
plt.show()

# %%
img = mp_image.imread(result_prefix + '_at_iteration_'+'%d.png' % 100)
plt.imshow(img)
plt.show()

# %% [markdown]
# # test

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import vgg19
import os

# %%
# VGG19 model 로딩 (pre-trained ImageNet weights)
model = vgg19.VGG19(weights="imagenet", include_top=False)
model.summary()

# 모델에서 레이어 이름과 레이어 출력 형식을 가져옴
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])

# VGG 모델의 전체 activation value를 출력하는 함수 정의
# (dict 형식)
feature_extractor = keras.Model(inputs=model.inputs, outputs=outputs_dict)

def preprocess_image(image_path, img_nrows, img_ncols):
    # Util function to open, resize and format pictures into appropriate tensors
    img = keras.preprocessing.image.load_img(
        image_path, target_size=(img_nrows, img_ncols)
    )
    img = keras.preprocessing.image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return tf.convert_to_tensor(img)


def deprocess_image(x, img_nrows, img_ncols):
    # Util function to convert a tensor into a valid image
    x = x.reshape((img_nrows, img_ncols, 3))
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype("uint8")
    return x

# 이미지 텐서의 gram matrix (특징별 outer product)

def gram_matrix(x):
    # 채널을 맨 앞으로, w,h를 뒤로 보냄
    x = tf.transpose(x, (2, 0, 1)) 
    # (c, h, w) ==> (c, w*h)
    features = tf.reshape(x, (tf.shape(x)[0], -1)) 
    # (c, w*h) x (w*h,c) = (c,c) 
    gram = tf.matmul(features, tf.transpose(features))  
    return gram

# style loss는 reference image와 generated image간의 
# 스타일 차이를 유지할 수 있도록 하는 역할을 한다.
# gram matrix의 차이의 squared error로 정의

def style_loss(style, combination, img_nrows, img_ncols):
    S = gram_matrix(style)
    C = gram_matrix(combination)
    # 논문의 정확한 implementation은 다음과 같아야 함
    # channels = style.shape[2]
    # size = style.shape[0] * style.shape[1] 
    channels = 3
    size = img_nrows * img_ncols
    return tf.reduce_sum(tf.square(S - C)) / (4.0 * (channels ** 2) * (size ** 2))

# 콘텐츠 손실 함수
# 생성된 이미지에서 base 이미지의 "content"를
# 유지하기 위함

def content_loss(base, combination):
    return tf.reduce_sum(tf.square(combination - base))

# 3번째 손실함수: total variation loss
# designed to keep the generated image locally coherent

def total_variation_loss(x, img_nrows, img_ncols):
    a = tf.square(
        x[:, : img_nrows - 1, : img_ncols - 1, :] - x[:, 1:, : img_ncols - 1, :]
    )
    b = tf.square(
        x[:, : img_nrows - 1, : img_ncols - 1, :] - x[:, : img_nrows - 1, 1:, :]
    )
    return tf.reduce_sum(tf.pow(a + b, 1.25))



def compute_loss(combination_image, base_image, style_reference_image, selected_style_layer_names, content_layer_name, total_variation_weight, style_weight, content_weight, img_nrows, img_ncols):
    input_tensor = tf.concat(
        [base_image, style_reference_image, combination_image], axis=0
    )
    features = feature_extractor(input_tensor)

    # loss 초기화
    loss = tf.zeros(shape=())

    # content loss
    layer_features = features[content_layer_name]
    base_image_features = layer_features[0, :, :, :]
    combination_features = layer_features[2, :, :, :]
    c_loss = content_weight * content_loss(
        base_image_features, combination_features
    )
    s_loss = tf.zeros(shape=())
    # Add style loss
    for layer_name in selected_style_layer_names:
        layer_features = features[layer_name]
        style_reference_features = layer_features[1, :, :, :]
        combination_features = layer_features[2, :, :, :]
        sl = style_loss(style_reference_features, combination_features, img_nrows, img_ncols)
        s_loss += (style_weight / len(selected_style_layer_names)) * sl
    
    # total variation loss
    t_loss = total_variation_weight * total_variation_loss(combination_image, img_nrows, img_ncols)
    loss = c_loss+s_loss+t_loss 
    return loss, c_loss, s_loss, t_loss

# 여러 복잡한 연산 실행히 빠른 실행을 위한 사전 컴파일
@tf.function
def compute_loss_and_grads(combination_image, base_image, style_reference_image, selected_style_layer_names, content_layer_name, total_variation_weight, style_weight, content_weight, img_nrows, img_ncols):
    # 안에서 일어나는 연산을 gradient를 추적할 수 있음.
    # loss를 계산할 때는 gradientTape 안에서 계산해야함.
    with tf.GradientTape() as tape:
        loss, c_loss, s_loss, t_loss = compute_loss(combination_image, base_image, style_reference_image, selected_style_layer_names, content_layer_name, total_variation_weight, style_weight, content_weight, img_nrows, img_ncols)
    grads = tape.gradient(loss, combination_image)
    return loss, grads, c_loss, s_loss, t_loss
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv4 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
def _main_call(_version_num, _base_img_name, _style_img_name, _style_layer_version, _style_layer_num):
    import platform
    # Weights of the different loss components
    total_variation_weight = 1e-6
    style_weight = 1e-6
    content_weight = 2.5e-8

    if _version_num == 2:
        total_variation_weight = 5e-7
        style_weight = 1e-5
        content_weight = 2.5e-8
    elif _version_num == 3:
        total_variation_weight = 1e-8
        style_weight = 5e-5 #generated6
        content_weight = 1e-10

    root_dir_path = '/content/drive/MyDrive/Colab Notebooks/data/data/gan_img_result'
    file_ext = 'jpeg'

    is_windows = platform.system().lower().__contains__("windows")
    if is_windows:
        root_dir_path = 'C:\\Users\\wivps\\Documents\\카카오톡 받은 파일\\transfer_image'
        file_ext = 'jpg'



    base_img_name = _base_img_name
    base_image_path = f"{root_dir_path}/{base_img_name}.{file_ext}"
    style_img_name = _style_img_name
    style_reference_image_path = f'{root_dir_path}/{style_img_name}.{file_ext}'

    img_version = 'v%d_%d_%d' % (_version_num, _style_layer_version, _style_layer_num)
    result_prefix = f'{root_dir_path}/{img_version}'

    from matplotlib import image as mp_image
    import matplotlib.pyplot as plt


    img = mp_image.imread(base_image_path)
    plt.imshow(img)
    plt.show()

    img = mp_image.imread(style_reference_image_path)
    plt.imshow(img)
    plt.show()


    # Dimensions of the generated picture.
    width, height = keras.preprocessing.image.load_img(base_image_path).size
    img_nrows = 800
    img_ncols = int(width * img_nrows / height)

    # VGG19 model 로딩 (pre-trained ImageNet weights)
    model = vgg19.VGG19(weights="imagenet", include_top=False)
    model.summary()

    # 모델에서 레이어 이름과 레이어 출력 형식을 가져옴
    outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])

    # VGG 모델의 전체 activation value를 출력하는 함수 정의
    # (dict 형식)
    feature_extractor = keras.Model(inputs=model.inputs, outputs=outputs_dict)

    # style loss에 사용할 레이어
    style_layer_names = ([
    "block1_conv1",
    "block2_conv1",
    "block3_conv1",
    "block4_conv1",
    "block5_conv1",
    ],[
        "block1_conv2",
        "block2_conv2",
        "block3_conv2",
        "block4_conv2",
        "block5_conv2",
    ])


    # content loss에 사용할 레이어
    selected_style_layer_names = style_layer_names[_style_layer_version]
    content_layer_name = selected_style_layer_names[_style_layer_num]
    print(content_layer_name)

    optimizer = keras.optimizers.SGD(
        keras.optimizers.schedules.ExponentialDecay( # 트레이닝이 길어질 때 learning rate를 점점 줄여주도록 하는 deco
            initial_learning_rate=100.0, decay_steps=100, decay_rate=0.96
        )
    )

    base_image = preprocess_image(base_image_path, img_nrows, img_ncols)
    style_reference_image = preprocess_image(style_reference_image_path, img_nrows, img_ncols)
    combination_image = tf.Variable(preprocess_image(base_image_path, img_nrows, img_ncols))

    # make dirs
    make_dir = f'{result_prefix}/{base_img_name}_{style_img_name}'
    # os.makedirs(make_dir, exist_ok=False)
    if not os.path.exists(make_dir):
        os.makedirs(make_dir)

    iterations = 1200
    for i in range(0, iterations + 1):
        loss, grads, c_loss, s_loss, t_loss = compute_loss_and_grads(
            combination_image, base_image, style_reference_image, selected_style_layer_names, content_layer_name, total_variation_weight, style_weight, content_weight, img_nrows, img_ncols
        )
        optimizer.apply_gradients([(grads, combination_image)])
        if i % 10 == 0 or i == 1:
            print("Iteration %d: loss=%.2f, content_loss=%.2f, style_loss=%.2f, total_variation_loss=%.2f" %
                (i, loss, c_loss, s_loss, t_loss))
        if (i < 30 and i % 5 == 0) or i % 100 == 0:
            img = deprocess_image(combination_image.numpy(), img_nrows, img_ncols)
            fname = f'{make_dir}/at_iteration_{i}.png'
            keras.preprocessing.image.save_img(fname, img)

# %%
_main_call(1, 'content_001', '001', 0, 4)
_main_call(1, 'content_001', '002', 0, 4)
_main_call(1, 'content_001', '003', 0, 4)
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv4 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________
# block5_conv1

# %%
_main_call(1, 'content_002', '001', 0, 4)
_main_call(1, 'content_002', '002', 0, 4)
_main_call(1, 'content_002', '003', 0, 4)
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_18 (InputLayer)       [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv4 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________
# block5_conv1
# Iteration 0: loss=312941.09, content_loss=0.00, style_loss=309897.97, total_variation_loss=3043.11
# Iteration 1: loss=178504.84, content_loss=188.24, style_loss=175012.44, total_variation_loss=3304.18
# Iteration 10: loss=446460.88, content_loss=359.10, style_loss=437336.44, total_variation_loss=8765.35
# Iteration 20: loss=51590.21, content_loss=390.16, style_loss=44512.86, total_variation_loss=6687.20
# Iteration 30: loss=28605.88, content_loss=377.06, style_loss=22786.36, total_variation_loss=5442.46
# Iteration 40: loss=25495.61, content_loss=395.01, style_loss=20298.00, total_variation_loss=4802.61
# Iteration 50: loss=22762.80, content_loss=386.69, style_loss=17990.79, total_variation_loss=4385.31
# Iteration 60: loss=17267.35, content_loss=389.77, style_loss=12810.87, total_variation_loss=4066.71
# Iteration 70: loss=15326.66, content_loss=391.35, style_loss=11093.96, total_variation_loss=3841.34
# Iteration 80: loss=15110.17, content_loss=390.05, style_loss=11060.85, total_variation_loss=3659.27
# Iteration 90: loss=14826.85, content_loss=385.99, style_loss=10892.32, total_variation_loss=3548.54
# Iteration 100: loss=14020.06, content_loss=397.00, style_loss=10209.97, total_variation_loss=3413.09
# Iteration 110: loss=12525.99, content_loss=390.08, style_loss=8822.09, total_variation_loss=3313.81
# Iteration 120: loss=11892.28, content_loss=387.88, style_loss=8254.44, total_variation_loss=3249.96
# Iteration 130: loss=11320.33, content_loss=389.39, style_loss=7774.25, total_variation_loss=3156.68
# Iteration 140: loss=10352.11, content_loss=387.33, style_loss=6889.57, total_variation_loss=3075.20
# Iteration 150: loss=11421.54, content_loss=389.96, style_loss=7990.36, total_variation_loss=3041.22
# Iteration 160: loss=10247.61, content_loss=384.11, style_loss=6868.04, total_variation_loss=2995.45
# Iteration 170: loss=11790.29, content_loss=392.76, style_loss=8427.85, total_variation_loss=2969.68
# Iteration 180: loss=9717.02, content_loss=387.64, style_loss=6422.74, total_variation_loss=2906.64
# Iteration 190: loss=9503.91, content_loss=383.61, style_loss=6245.85, total_variation_loss=2874.46
# Iteration 200: loss=9316.93, content_loss=383.06, style_loss=6089.70, total_variation_loss=2844.17
# Iteration 210: loss=8889.26, content_loss=384.57, style_loss=5705.41, total_variation_loss=2799.29
# Iteration 220: loss=9049.17, content_loss=386.63, style_loss=5890.68, total_variation_loss=2771.86
# Iteration 230: loss=8573.99, content_loss=380.53, style_loss=5457.78, total_variation_loss=2735.68
# Iteration 240: loss=10369.47, content_loss=370.53, style_loss=7316.71, total_variation_loss=2682.23
# Iteration 250: loss=9728.68, content_loss=372.03, style_loss=6688.81, total_variation_loss=2667.83
# Iteration 260: loss=8091.97, content_loss=378.15, style_loss=5033.67, total_variation_loss=2680.15
# Iteration 270: loss=8022.40, content_loss=376.40, style_loss=4988.30, total_variation_loss=2657.69
# Iteration 280: loss=8273.25, content_loss=373.43, style_loss=5261.97, total_variation_loss=2637.86
# Iteration 290: loss=7882.58, content_loss=373.58, style_loss=4898.96, total_variation_loss=2610.04
# Iteration 300: loss=9432.96, content_loss=366.06, style_loss=6503.79, total_variation_loss=2563.12
# Iteration 310: loss=8077.12, content_loss=373.47, style_loss=5120.29, total_variation_loss=2583.36
# Iteration 320: loss=8023.29, content_loss=378.65, style_loss=5052.19, total_variation_loss=2592.45
# Iteration 330: loss=7544.23, content_loss=376.71, style_loss=4594.76, total_variation_loss=2572.76
# Iteration 340: loss=7411.24, content_loss=375.33, style_loss=4482.08, total_variation_loss=2553.84
# Iteration 350: loss=7408.17, content_loss=375.52, style_loss=4489.48, total_variation_loss=2543.16
# Iteration 360: loss=7646.42, content_loss=376.92, style_loss=4730.38, total_variation_loss=2539.11
# Iteration 370: loss=7739.76, content_loss=373.14, style_loss=4846.46, total_variation_loss=2520.15
# Iteration 380: loss=8403.09, content_loss=364.73, style_loss=5549.00, total_variation_loss=2489.37
# Iteration 390: loss=7419.31, content_loss=369.59, style_loss=4563.77, total_variation_loss=2485.95
# Iteration 400: loss=7128.52, content_loss=371.75, style_loss=4274.16, total_variation_loss=2482.61
# Iteration 410: loss=7066.18, content_loss=371.79, style_loss=4221.71, total_variation_loss=2472.67
# Iteration 420: loss=7040.70, content_loss=371.52, style_loss=4205.66, total_variation_loss=2463.53
# Iteration 430: loss=7158.96, content_loss=372.01, style_loss=4324.11, total_variation_loss=2462.84
# Iteration 440: loss=7757.05, content_loss=375.88, style_loss=4900.89, total_variation_loss=2480.28
# Iteration 450: loss=7407.41, content_loss=374.02, style_loss=4569.06, total_variation_loss=2464.32
# Iteration 460: loss=6859.10, content_loss=369.11, style_loss=4051.16, total_variation_loss=2438.83
# Iteration 470: loss=6777.33, content_loss=367.89, style_loss=3980.96, total_variation_loss=2428.48
# Iteration 480: loss=6749.32, content_loss=366.66, style_loss=3963.93, total_variation_loss=2418.72
# Iteration 490: loss=6817.99, content_loss=364.61, style_loss=4045.01, total_variation_loss=2408.37
# Iteration 500: loss=6867.12, content_loss=363.03, style_loss=4103.37, total_variation_loss=2400.72
# Iteration 510: loss=6774.07, content_loss=362.89, style_loss=4016.86, total_variation_loss=2394.32
# Iteration 520: loss=7193.21, content_loss=362.47, style_loss=4440.98, total_variation_loss=2389.76
# Iteration 530: loss=6608.77, content_loss=365.61, style_loss=3846.50, total_variation_loss=2396.65
# Iteration 540: loss=6671.26, content_loss=366.85, style_loss=3906.05, total_variation_loss=2398.36
# Iteration 550: loss=6851.17, content_loss=368.03, style_loss=4082.72, total_variation_loss=2400.41
# Iteration 560: loss=6527.98, content_loss=366.06, style_loss=3776.49, total_variation_loss=2385.43
# Iteration 570: loss=6451.42, content_loss=364.84, style_loss=3711.95, total_variation_loss=2374.63
# Iteration 580: loss=6478.62, content_loss=364.68, style_loss=3745.14, total_variation_loss=2368.80
# Iteration 590: loss=6743.32, content_loss=363.79, style_loss=4015.20, total_variation_loss=2364.33
# Iteration 600: loss=6493.45, content_loss=360.65, style_loss=3779.51, total_variation_loss=2353.29
# Iteration 610: loss=6760.10, content_loss=357.67, style_loss=4063.61, total_variation_loss=2338.82
# Iteration 620: loss=6453.13, content_loss=359.69, style_loss=3752.24, total_variation_loss=2341.20
# Iteration 630: loss=6297.58, content_loss=360.98, style_loss=3593.45, total_variation_loss=2343.15
# Iteration 640: loss=6272.53, content_loss=360.68, style_loss=3572.94, total_variation_loss=2338.92
# Iteration 650: loss=6368.87, content_loss=360.31, style_loss=3674.16, total_variation_loss=2334.41
# Iteration 660: loss=6469.80, content_loss=360.51, style_loss=3775.02, total_variation_loss=2334.27
# Iteration 670: loss=6258.36, content_loss=361.21, style_loss=3562.15, total_variation_loss=2335.00
# Iteration 680: loss=6622.67, content_loss=363.96, style_loss=3915.97, total_variation_loss=2342.73
# Iteration 690: loss=6312.71, content_loss=361.35, style_loss=3615.83, total_variation_loss=2335.52
# Iteration 700: loss=6149.14, content_loss=358.65, style_loss=3467.54, total_variation_loss=2322.95
# Iteration 710: loss=6131.11, content_loss=357.65, style_loss=3456.74, total_variation_loss=2316.72
# Iteration 720: loss=6214.59, content_loss=356.74, style_loss=3546.63, total_variation_loss=2311.22
# Iteration 730: loss=6259.55, content_loss=356.01, style_loss=3597.10, total_variation_loss=2306.45
# Iteration 740: loss=6100.41, content_loss=355.47, style_loss=3442.89, total_variation_loss=2302.05
# Iteration 750: loss=6169.32, content_loss=354.04, style_loss=3520.36, total_variation_loss=2294.92
# Iteration 760: loss=6231.76, content_loss=353.36, style_loss=3588.25, total_variation_loss=2290.14
# Iteration 770: loss=6048.61, content_loss=354.50, style_loss=3401.97, total_variation_loss=2292.14
# Iteration 780: loss=5998.00, content_loss=354.65, style_loss=3352.15, total_variation_loss=2291.19
# Iteration 790: loss=5980.44, content_loss=354.09, style_loss=3338.53, total_variation_loss=2287.81
# Iteration 800: loss=5985.81, content_loss=353.03, style_loss=3349.70, total_variation_loss=2283.09
# Iteration 810: loss=6190.76, content_loss=351.39, style_loss=3561.68, total_variation_loss=2277.69
# Iteration 820: loss=6312.92, content_loss=353.04, style_loss=3676.71, total_variation_loss=2283.17
# Iteration 830: loss=6004.61, content_loss=355.14, style_loss=3361.06, total_variation_loss=2288.41
# Iteration 840: loss=6000.04, content_loss=355.11, style_loss=3358.20, total_variation_loss=2286.73
# Iteration 850: loss=5922.51, content_loss=353.97, style_loss=3287.67, total_variation_loss=2280.87
# Iteration 860: loss=5883.38, content_loss=353.09, style_loss=3254.41, total_variation_loss=2275.88
# Iteration 870: loss=5866.91, content_loss=352.65, style_loss=3241.52, total_variation_loss=2272.73
# Iteration 880: loss=5860.31, content_loss=352.47, style_loss=3237.21, total_variation_loss=2270.64
# Iteration 890: loss=5858.66, content_loss=352.32, style_loss=3237.45, total_variation_loss=2268.88
# Iteration 900: loss=5847.73, content_loss=351.97, style_loss=3229.21, total_variation_loss=2266.55
# Iteration 910: loss=5827.85, content_loss=351.33, style_loss=3213.23, total_variation_loss=2263.29
# Iteration 920: loss=5828.25, content_loss=350.41, style_loss=3218.44, total_variation_loss=2259.39
# Iteration 930: loss=5900.89, content_loss=348.85, style_loss=3298.35, total_variation_loss=2253.69
# Iteration 940: loss=5908.15, content_loss=347.71, style_loss=3312.18, total_variation_loss=2248.26
# Iteration 950: loss=5854.98, content_loss=347.82, style_loss=3260.75, total_variation_loss=2246.42
# Iteration 960: loss=5809.76, content_loss=348.33, style_loss=3214.74, total_variation_loss=2246.69
# Iteration 970: loss=5748.88, content_loss=348.72, style_loss=3153.13, total_variation_loss=2247.02
# Iteration 980: loss=5724.78, content_loss=348.65, style_loss=3130.33, total_variation_loss=2245.80
# Iteration 990: loss=5714.08, content_loss=348.47, style_loss=3121.58, total_variation_loss=2244.04
# Iteration 1000: loss=5711.82, content_loss=348.40, style_loss=3120.82, total_variation_loss=2242.60
# Iteration 1010: loss=5719.29, content_loss=348.60, style_loss=3128.50, total_variation_loss=2242.18
# Iteration 1020: loss=5745.13, content_loss=349.16, style_loss=3152.65, total_variation_loss=2243.33
# Iteration 1030: loss=5817.16, content_loss=349.54, style_loss=3222.75, total_variation_loss=2244.87
# Iteration 1040: loss=5775.20, content_loss=348.31, style_loss=3185.66, total_variation_loss=2241.23
# Iteration 1050: loss=5673.67, content_loss=346.70, style_loss=3092.31, total_variation_loss=2234.67
# Iteration 1060: loss=5647.96, content_loss=345.96, style_loss=3071.13, total_variation_loss=2230.87
# Iteration 1070: loss=5637.45, content_loss=345.53, style_loss=3063.53, total_variation_loss=2228.39
# Iteration 1080: loss=5627.83, content_loss=345.21, style_loss=3056.22, total_variation_loss=2226.41
# Iteration 1090: loss=5616.30, content_loss=344.97, style_loss=3046.58, total_variation_loss=2224.75
# Iteration 1100: loss=5604.07, content_loss=344.78, style_loss=3035.98, total_variation_loss=2223.31
# Iteration 1110: loss=5593.51, content_loss=344.63, style_loss=3026.83, total_variation_loss=2222.05
# Iteration 1120: loss=5588.78, content_loss=344.58, style_loss=3023.00, total_variation_loss=2221.20
# Iteration 1130: loss=5602.86, content_loss=344.83, style_loss=3036.63, total_variation_loss=2221.40
# Iteration 1140: loss=5628.80, content_loss=345.37, style_loss=3060.84, total_variation_loss=2222.59
# Iteration 1150: loss=5609.27, content_loss=345.50, style_loss=3041.70, total_variation_loss=2222.06
# Iteration 1160: loss=5578.53, content_loss=345.01, style_loss=3014.12, total_variation_loss=2219.39
# Iteration 1170: loss=5558.08, content_loss=344.33, style_loss=2997.42, total_variation_loss=2216.33
# Iteration 1180: loss=5542.11, content_loss=343.67, style_loss=2984.91, total_variation_loss=2213.53
# Iteration 1190: loss=5527.16, content_loss=343.12, style_loss=2972.87, total_variation_loss=2211.17
# Iteration 1200: loss=5514.66, content_loss=342.66, style_loss=2962.87, total_variation_loss=2209.12
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_19 (InputLayer)       [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv4 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________
# block5_conv1
# Iteration 0: loss=420501.62, content_loss=0.00, style_loss=417458.50, total_variation_loss=3043.11
# Iteration 1: loss=197884.75, content_loss=196.53, style_loss=194443.30, total_variation_loss=3244.92
# Iteration 10: loss=431739.91, content_loss=335.15, style_loss=422491.72, total_variation_loss=8913.03
# Iteration 20: loss=41483.17, content_loss=334.62, style_loss=34697.80, total_variation_loss=6450.74
# Iteration 30: loss=26892.19, content_loss=328.14, style_loss=21252.35, total_variation_loss=5311.69
# Iteration 40: loss=21590.32, content_loss=328.78, style_loss=16545.16, total_variation_loss=4716.38
# Iteration 50: loss=17953.50, content_loss=326.49, style_loss=13314.79, total_variation_loss=4312.21
# Iteration 60: loss=16619.41, content_loss=326.72, style_loss=12244.21, total_variation_loss=4048.48
# Iteration 70: loss=15265.12, content_loss=327.13, style_loss=11121.41, total_variation_loss=3816.58
# Iteration 80: loss=14155.68, content_loss=322.40, style_loss=10173.72, total_variation_loss=3659.56
# Iteration 90: loss=17707.76, content_loss=311.44, style_loss=13933.76, total_variation_loss=3462.56
# Iteration 100: loss=12401.73, content_loss=322.72, style_loss=8681.33, total_variation_loss=3397.68
# Iteration 110: loss=11544.96, content_loss=321.91, style_loss=7925.39, total_variation_loss=3297.67
# Iteration 120: loss=11707.51, content_loss=318.73, style_loss=8188.69, total_variation_loss=3200.09
# Iteration 130: loss=12796.42, content_loss=314.41, style_loss=9374.78, total_variation_loss=3107.23
# Iteration 140: loss=10721.53, content_loss=320.32, style_loss=7323.34, total_variation_loss=3077.88
# Iteration 150: loss=10647.96, content_loss=322.49, style_loss=7287.81, total_variation_loss=3037.66
# Iteration 160: loss=10525.01, content_loss=324.29, style_loss=7200.04, total_variation_loss=3000.67
# Iteration 170: loss=10234.42, content_loss=323.88, style_loss=6963.31, total_variation_loss=2947.22
# Iteration 180: loss=9713.71, content_loss=320.96, style_loss=6496.44, total_variation_loss=2896.30
# Iteration 190: loss=9954.62, content_loss=317.17, style_loss=6785.65, total_variation_loss=2851.80
# Iteration 200: loss=10913.38, content_loss=312.34, style_loss=7803.17, total_variation_loss=2797.87
# Iteration 210: loss=9407.13, content_loss=316.66, style_loss=6300.09, total_variation_loss=2790.38
# Iteration 220: loss=8987.06, content_loss=317.17, style_loss=5900.72, total_variation_loss=2769.17
# Iteration 230: loss=9074.87, content_loss=316.11, style_loss=6017.52, total_variation_loss=2741.23
# Iteration 240: loss=9002.14, content_loss=315.79, style_loss=5967.97, total_variation_loss=2718.38
# Iteration 250: loss=8639.25, content_loss=316.17, style_loss=5629.15, total_variation_loss=2693.93
# Iteration 260: loss=10016.86, content_loss=321.38, style_loss=6998.11, total_variation_loss=2697.37
# Iteration 270: loss=8617.22, content_loss=316.87, style_loss=5624.07, total_variation_loss=2676.27
# Iteration 280: loss=8519.20, content_loss=313.99, style_loss=5562.02, total_variation_loss=2643.19
# Iteration 290: loss=8738.12, content_loss=313.57, style_loss=5800.12, total_variation_loss=2624.42
# Iteration 300: loss=8268.24, content_loss=313.22, style_loss=5352.87, total_variation_loss=2602.16
# Iteration 310: loss=8215.54, content_loss=311.88, style_loss=5322.94, total_variation_loss=2580.72
# Iteration 320: loss=8355.14, content_loss=309.44, style_loss=5486.50, total_variation_loss=2559.19
# Iteration 330: loss=8380.13, content_loss=308.14, style_loss=5524.98, total_variation_loss=2547.01
# Iteration 340: loss=7992.87, content_loss=309.72, style_loss=5140.59, total_variation_loss=2542.56
# Iteration 350: loss=8115.36, content_loss=310.36, style_loss=5271.65, total_variation_loss=2533.35
# Iteration 360: loss=8014.87, content_loss=310.87, style_loss=5179.53, total_variation_loss=2524.47
# Iteration 370: loss=7804.53, content_loss=310.71, style_loss=4980.27, total_variation_loss=2513.55
# Iteration 380: loss=8443.78, content_loss=312.45, style_loss=5613.81, total_variation_loss=2517.51
# Iteration 390: loss=7844.90, content_loss=310.37, style_loss=5029.33, total_variation_loss=2505.20
# Iteration 400: loss=7610.77, content_loss=308.36, style_loss=4819.33, total_variation_loss=2483.09
# Iteration 410: loss=7608.02, content_loss=307.55, style_loss=4830.89, total_variation_loss=2469.58
# Iteration 420: loss=7790.04, content_loss=306.72, style_loss=5025.29, total_variation_loss=2458.03
# Iteration 430: loss=7556.08, content_loss=305.89, style_loss=4801.03, total_variation_loss=2449.17
# Iteration 440: loss=7544.78, content_loss=304.49, style_loss=4803.42, total_variation_loss=2436.87
# Iteration 450: loss=7944.92, content_loss=302.87, style_loss=5218.52, total_variation_loss=2423.53
# Iteration 460: loss=7454.25, content_loss=304.58, style_loss=4724.93, total_variation_loss=2424.73
# Iteration 470: loss=7325.04, content_loss=304.86, style_loss=4600.02, total_variation_loss=2420.16
# Iteration 480: loss=7284.23, content_loss=304.32, style_loss=4568.06, total_variation_loss=2411.85
# Iteration 490: loss=7261.26, content_loss=303.49, style_loss=4555.06, total_variation_loss=2402.71
# Iteration 500: loss=7353.28, content_loss=301.92, style_loss=4659.71, total_variation_loss=2391.65
# Iteration 510: loss=7592.77, content_loss=300.33, style_loss=4910.56, total_variation_loss=2381.88
# Iteration 520: loss=7600.53, content_loss=301.44, style_loss=4917.77, total_variation_loss=2381.32
# Iteration 530: loss=7384.66, content_loss=303.11, style_loss=4694.75, total_variation_loss=2386.81
# Iteration 540: loss=7133.30, content_loss=302.84, style_loss=4448.87, total_variation_loss=2381.58
# Iteration 550: loss=7097.36, content_loss=302.38, style_loss=4420.33, total_variation_loss=2374.64
# Iteration 560: loss=7076.14, content_loss=302.03, style_loss=4405.41, total_variation_loss=2368.69
# Iteration 570: loss=7059.89, content_loss=301.71, style_loss=4394.78, total_variation_loss=2363.41
# Iteration 580: loss=7036.03, content_loss=301.31, style_loss=4376.64, total_variation_loss=2358.08
# Iteration 590: loss=7001.84, content_loss=300.80, style_loss=4348.65, total_variation_loss=2352.39
# Iteration 600: loss=6970.90, content_loss=300.31, style_loss=4323.73, total_variation_loss=2346.86
# Iteration 610: loss=6947.60, content_loss=299.89, style_loss=4305.90, total_variation_loss=2341.81
# Iteration 620: loss=6926.87, content_loss=299.48, style_loss=4290.39, total_variation_loss=2337.00
# Iteration 630: loss=6904.66, content_loss=299.02, style_loss=4273.57, total_variation_loss=2332.07
# Iteration 640: loss=6886.39, content_loss=298.42, style_loss=4261.40, total_variation_loss=2326.56
# Iteration 650: loss=6931.57, content_loss=297.25, style_loss=4315.52, total_variation_loss=2318.80
# Iteration 660: loss=7187.35, content_loss=295.37, style_loss=4582.91, total_variation_loss=2309.08
# Iteration 670: loss=6997.78, content_loss=296.02, style_loss=4390.82, total_variation_loss=2310.95
# Iteration 680: loss=6810.51, content_loss=296.94, style_loss=4201.02, total_variation_loss=2312.55
# Iteration 690: loss=6761.80, content_loss=296.79, style_loss=4155.99, total_variation_loss=2309.02
# Iteration 700: loss=6738.77, content_loss=296.42, style_loss=4137.61, total_variation_loss=2304.75
# Iteration 710: loss=6723.02, content_loss=296.02, style_loss=4126.41, total_variation_loss=2300.59
# Iteration 720: loss=6713.96, content_loss=295.56, style_loss=4122.02, total_variation_loss=2296.38
# Iteration 730: loss=6716.86, content_loss=294.89, style_loss=4130.53, total_variation_loss=2291.43
# Iteration 740: loss=6785.31, content_loss=293.83, style_loss=4206.39, total_variation_loss=2285.09
# Iteration 750: loss=6824.94, content_loss=293.26, style_loss=4250.88, total_variation_loss=2280.79
# Iteration 760: loss=6676.79, content_loss=293.79, style_loss=4101.80, total_variation_loss=2281.20
# Iteration 770: loss=6632.08, content_loss=293.98, style_loss=4057.98, total_variation_loss=2280.12
# Iteration 780: loss=6627.37, content_loss=293.97, style_loss=4055.25, total_variation_loss=2278.15
# Iteration 790: loss=6625.68, content_loss=293.96, style_loss=4055.31, total_variation_loss=2276.41
# Iteration 800: loss=6606.98, content_loss=293.87, style_loss=4038.61, total_variation_loss=2274.51
# Iteration 810: loss=6584.63, content_loss=293.64, style_loss=4018.98, total_variation_loss=2272.02
# Iteration 820: loss=6565.84, content_loss=293.32, style_loss=4003.37, total_variation_loss=2269.15
# Iteration 830: loss=6545.29, content_loss=292.92, style_loss=3986.36, total_variation_loss=2266.01
# Iteration 840: loss=6524.32, content_loss=292.49, style_loss=3969.16, total_variation_loss=2262.68
# Iteration 850: loss=6510.57, content_loss=292.00, style_loss=3959.32, total_variation_loss=2259.26
# Iteration 860: loss=6532.10, content_loss=291.29, style_loss=3985.63, total_variation_loss=2255.18
# Iteration 870: loss=6605.85, content_loss=290.40, style_loss=4064.92, total_variation_loss=2250.52
# Iteration 880: loss=6536.88, content_loss=290.14, style_loss=3998.57, total_variation_loss=2248.17
# Iteration 890: loss=6466.29, content_loss=290.28, style_loss=3928.73, total_variation_loss=2247.28
# Iteration 900: loss=6438.20, content_loss=290.23, style_loss=3902.24, total_variation_loss=2245.72
# Iteration 910: loss=6421.56, content_loss=290.03, style_loss=3887.88, total_variation_loss=2243.64
# Iteration 920: loss=6408.43, content_loss=289.79, style_loss=3877.27, total_variation_loss=2241.37
# Iteration 930: loss=6396.87, content_loss=289.55, style_loss=3868.16, total_variation_loss=2239.17
# Iteration 940: loss=6387.53, content_loss=289.38, style_loss=3860.88, total_variation_loss=2237.28
# Iteration 950: loss=6390.71, content_loss=289.40, style_loss=3865.09, total_variation_loss=2236.22
# Iteration 960: loss=6434.00, content_loss=289.68, style_loss=3907.77, total_variation_loss=2236.55
# Iteration 970: loss=6434.88, content_loss=289.67, style_loss=3909.18, total_variation_loss=2236.04
# Iteration 980: loss=6361.42, content_loss=289.02, style_loss=3839.92, total_variation_loss=2232.48
# Iteration 990: loss=6329.58, content_loss=288.47, style_loss=3812.04, total_variation_loss=2229.07
# Iteration 1000: loss=6315.20, content_loss=288.11, style_loss=3800.54, total_variation_loss=2226.55
# Iteration 1010: loss=6304.35, content_loss=287.83, style_loss=3792.09, total_variation_loss=2224.43
# Iteration 1020: loss=6294.86, content_loss=287.56, style_loss=3784.91, total_variation_loss=2222.39
# Iteration 1030: loss=6287.20, content_loss=287.24, style_loss=3779.73, total_variation_loss=2220.22
# Iteration 1040: loss=6286.94, content_loss=286.82, style_loss=3782.41, total_variation_loss=2217.71
# Iteration 1050: loss=6302.51, content_loss=286.31, style_loss=3801.30, total_variation_loss=2214.90
# Iteration 1060: loss=6302.48, content_loss=285.94, style_loss=3803.85, total_variation_loss=2212.69
# Iteration 1070: loss=6266.55, content_loss=285.88, style_loss=3769.10, total_variation_loss=2211.57
# Iteration 1080: loss=6240.31, content_loss=285.87, style_loss=3743.85, total_variation_loss=2210.58
# Iteration 1090: loss=6226.21, content_loss=285.75, style_loss=3731.20, total_variation_loss=2209.25
# Iteration 1100: loss=6216.23, content_loss=285.57, style_loss=3722.98, total_variation_loss=2207.69
# Iteration 1110: loss=6208.18, content_loss=285.36, style_loss=3716.77, total_variation_loss=2206.05
# Iteration 1120: loss=6201.40, content_loss=285.14, style_loss=3711.80, total_variation_loss=2204.45
# Iteration 1130: loss=6194.49, content_loss=284.95, style_loss=3706.59, total_variation_loss=2202.95
# Iteration 1140: loss=6185.45, content_loss=284.78, style_loss=3699.14, total_variation_loss=2201.53
# Iteration 1150: loss=6174.88, content_loss=284.61, style_loss=3690.15, total_variation_loss=2200.12
# Iteration 1160: loss=6164.76, content_loss=284.42, style_loss=3681.65, total_variation_loss=2198.69
# Iteration 1170: loss=6155.65, content_loss=284.23, style_loss=3674.20, total_variation_loss=2197.22
# Iteration 1180: loss=6147.24, content_loss=284.03, style_loss=3667.44, total_variation_loss=2195.76
# Iteration 1190: loss=6139.11, content_loss=283.83, style_loss=3660.94, total_variation_loss=2194.33
# Iteration 1200: loss=6130.97, content_loss=283.64, style_loss=3654.37, total_variation_loss=2192.96
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv4 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________
# block5_conv1
# Iteration 0: loss=220451.50, content_loss=0.00, style_loss=217408.39, total_variation_loss=3043.11
# Iteration 1: loss=188367.91, content_loss=181.21, style_loss=185204.78, total_variation_loss=2981.91
# Iteration 10: loss=146789.47, content_loss=250.16, style_loss=143060.16, total_variation_loss=3479.16
# Iteration 20: loss=27454.28, content_loss=248.16, style_loss=24267.30, total_variation_loss=2938.82
# Iteration 30: loss=24236.93, content_loss=239.07, style_loss=21419.87, total_variation_loss=2578.00
# Iteration 40: loss=19381.16, content_loss=247.13, style_loss=16725.62, total_variation_loss=2408.41
# Iteration 50: loss=16118.96, content_loss=250.05, style_loss=13625.50, total_variation_loss=2243.41
# Iteration 60: loss=16425.20, content_loss=254.17, style_loss=14028.48, total_variation_loss=2142.55
# Iteration 70: loss=14875.40, content_loss=250.31, style_loss=12565.11, total_variation_loss=2059.97
# Iteration 80: loss=13392.45, content_loss=248.50, style_loss=11198.52, total_variation_loss=1945.43
# Iteration 90: loss=13202.12, content_loss=249.12, style_loss=11051.75, total_variation_loss=1901.24
# Iteration 100: loss=12786.83, content_loss=252.58, style_loss=10704.33, total_variation_loss=1829.92
# Iteration 110: loss=12661.60, content_loss=256.87, style_loss=10586.10, total_variation_loss=1818.62
# Iteration 120: loss=11298.48, content_loss=254.66, style_loss=9285.01, total_variation_loss=1758.81
# Iteration 130: loss=11788.02, content_loss=257.18, style_loss=9821.49, total_variation_loss=1709.35
# Iteration 140: loss=10616.34, content_loss=254.15, style_loss=8679.08, total_variation_loss=1683.11
# Iteration 150: loss=10794.39, content_loss=253.06, style_loss=8898.45, total_variation_loss=1642.88
# Iteration 160: loss=10579.61, content_loss=258.62, style_loss=8688.67, total_variation_loss=1632.31
# Iteration 170: loss=10418.38, content_loss=256.04, style_loss=8553.47, total_variation_loss=1608.87
# Iteration 180: loss=11945.01, content_loss=255.51, style_loss=10097.77, total_variation_loss=1591.73
# Iteration 190: loss=9851.05, content_loss=258.91, style_loss=8029.13, total_variation_loss=1563.01
# Iteration 200: loss=9695.09, content_loss=259.81, style_loss=7890.33, total_variation_loss=1544.95
# Iteration 210: loss=9555.07, content_loss=260.07, style_loss=7755.00, total_variation_loss=1540.01
# Iteration 220: loss=8862.77, content_loss=258.00, style_loss=7100.04, total_variation_loss=1504.73
# Iteration 230: loss=9062.21, content_loss=257.03, style_loss=7316.21, total_variation_loss=1488.97
# Iteration 240: loss=9134.80, content_loss=258.65, style_loss=7399.56, total_variation_loss=1476.60
# Iteration 250: loss=9842.95, content_loss=260.78, style_loss=8097.50, total_variation_loss=1484.67
# Iteration 260: loss=9002.42, content_loss=258.44, style_loss=7292.23, total_variation_loss=1451.74
# Iteration 270: loss=8738.71, content_loss=257.41, style_loss=7048.50, total_variation_loss=1432.80
# Iteration 280: loss=8115.40, content_loss=259.40, style_loss=6437.64, total_variation_loss=1418.36
# Iteration 290: loss=8344.75, content_loss=258.66, style_loss=6680.88, total_variation_loss=1405.21
# Iteration 300: loss=8024.21, content_loss=259.01, style_loss=6370.34, total_variation_loss=1394.87
# Iteration 310: loss=7963.14, content_loss=258.89, style_loss=6320.14, total_variation_loss=1384.11
# Iteration 320: loss=7977.52, content_loss=260.35, style_loss=6334.57, total_variation_loss=1382.60
# Iteration 330: loss=8238.03, content_loss=259.50, style_loss=6608.28, total_variation_loss=1370.24
# Iteration 340: loss=7954.02, content_loss=258.86, style_loss=6336.71, total_variation_loss=1358.45
# Iteration 350: loss=7792.25, content_loss=262.55, style_loss=6175.70, total_variation_loss=1354.01
# Iteration 360: loss=7363.60, content_loss=262.05, style_loss=5754.10, total_variation_loss=1347.45
# Iteration 370: loss=7537.81, content_loss=261.13, style_loss=5935.39, total_variation_loss=1341.29
# Iteration 380: loss=8261.82, content_loss=261.93, style_loss=6658.67, total_variation_loss=1341.22
# Iteration 390: loss=9338.01, content_loss=258.90, style_loss=7737.24, total_variation_loss=1341.86
# Iteration 400: loss=7820.19, content_loss=262.65, style_loss=6221.40, total_variation_loss=1336.14
# Iteration 410: loss=7083.84, content_loss=262.02, style_loss=5505.07, total_variation_loss=1316.75
# Iteration 420: loss=7132.26, content_loss=260.72, style_loss=5570.31, total_variation_loss=1301.23
# Iteration 430: loss=6836.75, content_loss=261.76, style_loss=5278.54, total_variation_loss=1296.45
# Iteration 440: loss=6790.30, content_loss=262.62, style_loss=5237.82, total_variation_loss=1289.86
# Iteration 450: loss=7000.63, content_loss=263.20, style_loss=5454.97, total_variation_loss=1282.46
# Iteration 460: loss=6796.64, content_loss=260.76, style_loss=5263.74, total_variation_loss=1272.14
# Iteration 470: loss=6898.69, content_loss=261.39, style_loss=5371.77, total_variation_loss=1265.53
# Iteration 480: loss=6628.29, content_loss=262.59, style_loss=5105.55, total_variation_loss=1260.15
# Iteration 490: loss=6565.97, content_loss=262.32, style_loss=5046.32, total_variation_loss=1257.33
# Iteration 500: loss=6384.28, content_loss=262.36, style_loss=4869.83, total_variation_loss=1252.10
# Iteration 510: loss=6522.05, content_loss=263.02, style_loss=5014.52, total_variation_loss=1244.50
# Iteration 520: loss=6554.81, content_loss=263.62, style_loss=5046.35, total_variation_loss=1244.84
# Iteration 530: loss=6340.91, content_loss=262.31, style_loss=4838.74, total_variation_loss=1239.86
# Iteration 540: loss=6947.23, content_loss=262.13, style_loss=5449.50, total_variation_loss=1235.60
# Iteration 550: loss=6453.85, content_loss=261.99, style_loss=4963.84, total_variation_loss=1228.02
# Iteration 560: loss=6181.53, content_loss=261.16, style_loss=4700.99, total_variation_loss=1219.38
# Iteration 570: loss=6116.49, content_loss=261.66, style_loss=4636.87, total_variation_loss=1217.97
# Iteration 580: loss=6029.28, content_loss=262.77, style_loss=4553.17, total_variation_loss=1213.34
# Iteration 590: loss=5968.39, content_loss=262.84, style_loss=4499.24, total_variation_loss=1206.31
# Iteration 600: loss=5942.51, content_loss=262.53, style_loss=4479.56, total_variation_loss=1200.41
# Iteration 610: loss=5966.05, content_loss=262.19, style_loss=4505.63, total_variation_loss=1198.23
# Iteration 620: loss=6116.78, content_loss=261.80, style_loss=4658.96, total_variation_loss=1196.02
# Iteration 630: loss=5893.01, content_loss=262.46, style_loss=4437.63, total_variation_loss=1192.92
# Iteration 640: loss=6173.55, content_loss=260.67, style_loss=4730.81, total_variation_loss=1182.06
# Iteration 650: loss=5732.84, content_loss=261.50, style_loss=4292.22, total_variation_loss=1179.12
# Iteration 660: loss=5858.01, content_loss=261.41, style_loss=4419.96, total_variation_loss=1176.64
# Iteration 670: loss=5605.04, content_loss=261.83, style_loss=4172.14, total_variation_loss=1171.06
# Iteration 680: loss=5567.04, content_loss=262.11, style_loss=4138.77, total_variation_loss=1166.16
# Iteration 690: loss=5871.64, content_loss=263.14, style_loss=4446.20, total_variation_loss=1162.30
# Iteration 700: loss=5593.12, content_loss=261.78, style_loss=4169.27, total_variation_loss=1162.07
# Iteration 710: loss=5444.48, content_loss=262.12, style_loss=4023.56, total_variation_loss=1158.79
# Iteration 720: loss=5553.00, content_loss=262.88, style_loss=4134.95, total_variation_loss=1155.18
# Iteration 730: loss=5500.25, content_loss=262.88, style_loss=4084.40, total_variation_loss=1152.97
# Iteration 740: loss=5460.84, content_loss=262.26, style_loss=4048.92, total_variation_loss=1149.67
# Iteration 750: loss=5428.10, content_loss=261.36, style_loss=4023.12, total_variation_loss=1143.62
# Iteration 760: loss=5331.27, content_loss=261.48, style_loss=3929.77, total_variation_loss=1140.02
# Iteration 770: loss=5476.35, content_loss=261.97, style_loss=4074.20, total_variation_loss=1140.19
# Iteration 780: loss=5314.88, content_loss=262.49, style_loss=3917.58, total_variation_loss=1134.81
# Iteration 790: loss=5297.87, content_loss=262.60, style_loss=3905.27, total_variation_loss=1129.99
# Iteration 800: loss=5240.13, content_loss=261.80, style_loss=3852.58, total_variation_loss=1125.76
# Iteration 810: loss=5130.67, content_loss=261.20, style_loss=3746.58, total_variation_loss=1122.89
# Iteration 820: loss=5196.53, content_loss=261.09, style_loss=3815.18, total_variation_loss=1120.27
# Iteration 830: loss=5121.71, content_loss=261.63, style_loss=3743.64, total_variation_loss=1116.44
# Iteration 840: loss=5104.00, content_loss=261.63, style_loss=3727.48, total_variation_loss=1114.89
# Iteration 850: loss=5208.95, content_loss=261.61, style_loss=3832.16, total_variation_loss=1115.17
# Iteration 860: loss=5142.56, content_loss=261.25, style_loss=3770.03, total_variation_loss=1111.28
# Iteration 870: loss=5028.00, content_loss=260.83, style_loss=3662.80, total_variation_loss=1104.37
# Iteration 880: loss=4928.21, content_loss=261.17, style_loss=3564.81, total_variation_loss=1102.23
# Iteration 890: loss=4970.87, content_loss=261.26, style_loss=3609.25, total_variation_loss=1100.36
# Iteration 900: loss=5115.61, content_loss=261.95, style_loss=3754.89, total_variation_loss=1098.78
# Iteration 910: loss=4901.37, content_loss=261.62, style_loss=3544.58, total_variation_loss=1095.17
# Iteration 920: loss=4855.01, content_loss=261.33, style_loss=3502.50, total_variation_loss=1091.18
# Iteration 930: loss=5124.33, content_loss=262.61, style_loss=3772.33, total_variation_loss=1089.39
# Iteration 940: loss=4865.56, content_loss=261.93, style_loss=3513.12, total_variation_loss=1090.51
# Iteration 950: loss=4807.58, content_loss=261.79, style_loss=3457.93, total_variation_loss=1087.86
# Iteration 960: loss=4781.51, content_loss=261.59, style_loss=3436.89, total_variation_loss=1083.04
# Iteration 970: loss=4778.90, content_loss=261.56, style_loss=3437.61, total_variation_loss=1079.73
# Iteration 980: loss=4709.40, content_loss=261.64, style_loss=3369.49, total_variation_loss=1078.27
# Iteration 990: loss=4805.72, content_loss=261.83, style_loss=3468.67, total_variation_loss=1075.22
# Iteration 1000: loss=4650.43, content_loss=261.39, style_loss=3316.17, total_variation_loss=1072.86
# Iteration 1010: loss=4671.04, content_loss=261.40, style_loss=3338.95, total_variation_loss=1070.69
# Iteration 1020: loss=4735.87, content_loss=261.74, style_loss=3402.86, total_variation_loss=1071.27
# Iteration 1030: loss=4769.45, content_loss=260.90, style_loss=3440.52, total_variation_loss=1068.03
# Iteration 1040: loss=4668.80, content_loss=261.40, style_loss=3344.01, total_variation_loss=1063.39
# Iteration 1050: loss=4615.42, content_loss=261.70, style_loss=3291.90, total_variation_loss=1061.81
# Iteration 1060: loss=4556.48, content_loss=261.43, style_loss=3234.23, total_variation_loss=1060.82
# Iteration 1070: loss=4515.01, content_loss=261.18, style_loss=3195.26, total_variation_loss=1058.57
# Iteration 1080: loss=4528.28, content_loss=260.86, style_loss=3211.43, total_variation_loss=1055.99
# Iteration 1090: loss=4537.00, content_loss=260.46, style_loss=3224.88, total_variation_loss=1051.66
# Iteration 1100: loss=4620.02, content_loss=261.20, style_loss=3308.46, total_variation_loss=1050.36
# Iteration 1110: loss=4512.96, content_loss=261.61, style_loss=3201.36, total_variation_loss=1049.99
# Iteration 1120: loss=4467.67, content_loss=261.30, style_loss=3159.28, total_variation_loss=1047.09
# Iteration 1130: loss=4453.42, content_loss=261.11, style_loss=3147.72, total_variation_loss=1044.60
# Iteration 1140: loss=4425.29, content_loss=260.80, style_loss=3121.82, total_variation_loss=1042.67
# Iteration 1150: loss=4412.20, content_loss=260.63, style_loss=3110.74, total_variation_loss=1040.83
# Iteration 1160: loss=4362.26, content_loss=260.76, style_loss=3062.00, total_variation_loss=1039.50
# Iteration 1170: loss=4473.10, content_loss=261.06, style_loss=3175.26, total_variation_loss=1036.78
# Iteration 1180: loss=4420.86, content_loss=261.38, style_loss=3125.05, total_variation_loss=1034.43
# Iteration 1190: loss=4322.65, content_loss=260.85, style_loss=3028.20, total_variation_loss=1033.60
# Iteration 1200: loss=4333.26, content_loss=260.44, style_loss=3041.25, total_variation_loss=1031.57

# %% [markdown]
# ## content_001.jpeg
#
# ### style_001.jpeg

# %%
_main_call(1, 'content_001', '001', 0, 0)
_main_call(1, 'content_001', '001', 0, 1)
_main_call(1, 'content_001', '001', 0, 2)
_main_call(1, 'content_001', '001', 0, 3)
_main_call(1, 'content_001', '001', 0, 4)

_main_call(1, 'content_001', '001', 1, 0)
_main_call(1, 'content_001', '001', 1, 1)
_main_call(1, 'content_001', '001', 1, 2)
_main_call(1, 'content_001', '001', 1, 3)
_main_call(1, 'content_001', '001', 1, 4)

_main_call(2, 'content_001', '001', 0, 0)
_main_call(2, 'content_001', '001', 0, 1)
_main_call(2, 'content_001', '001', 0, 2)
_main_call(2, 'content_001', '001', 0, 3)
_main_call(2, 'content_001', '001', 0, 4)

_main_call(2, 'content_001', '001', 1, 0)
_main_call(2, 'content_001', '001', 1, 1)
_main_call(2, 'content_001', '001', 1, 2)
_main_call(2, 'content_001', '001', 1, 3)
_main_call(2, 'content_001', '001', 1, 4)

_main_call(3, 'content_001', '001', 0, 0)
_main_call(3, 'content_001', '001', 0, 1)
_main_call(3, 'content_001', '001', 0, 2)
_main_call(3, 'content_001', '001', 0, 3)
_main_call(3, 'content_001', '001', 0, 4)

_main_call(3, 'content_001', '001', 1, 0)
_main_call(3, 'content_001', '001', 1, 1)
_main_call(3, 'content_001', '001', 1, 2)
_main_call(3, 'content_001', '001', 1, 3)
_main_call(3, 'content_001', '001', 1, 4)

# %% [markdown]
# ### style_002.jpeg

# %%
_main_call(1, 'content_001', '002', 0, 0)
_main_call(1, 'content_001', '002', 0, 1)
_main_call(1, 'content_001', '002', 0, 2)
_main_call(1, 'content_001', '002', 0, 3)
_main_call(1, 'content_001', '002', 0, 4)

_main_call(1, 'content_001', '002', 1, 0)
_main_call(1, 'content_001', '002', 1, 1)
_main_call(1, 'content_001', '002', 1, 2)
_main_call(1, 'content_001', '002', 1, 3)
_main_call(1, 'content_001', '002', 1, 4)

_main_call(2, 'content_001', '002', 0, 0)
_main_call(2, 'content_001', '002', 0, 1)
_main_call(2, 'content_001', '002', 0, 2)
_main_call(2, 'content_001', '002', 0, 3)
_main_call(2, 'content_001', '002', 0, 4)

_main_call(2, 'content_001', '002', 1, 0)
_main_call(2, 'content_001', '002', 1, 1)
_main_call(2, 'content_001', '002', 1, 2)
_main_call(2, 'content_001', '002', 1, 3)
_main_call(2, 'content_001', '002', 1, 4)

_main_call(3, 'content_001', '002', 0, 0)
_main_call(3, 'content_001', '002', 0, 1)
_main_call(3, 'content_001', '002', 0, 2)
_main_call(3, 'content_001', '002', 0, 3)
_main_call(3, 'content_001', '002', 0, 4)

_main_call(3, 'content_001', '002', 1, 0)
_main_call(3, 'content_001', '002', 1, 1)
_main_call(3, 'content_001', '002', 1, 2)
_main_call(3, 'content_001', '002', 1, 3)
_main_call(3, 'content_001', '002', 1, 4)

# %% [markdown]
# ### style_003.jpeg

# %%
_main_call(1, 'content_001', '003', 0, 0)
_main_call(1, 'content_001', '003', 0, 1)
_main_call(1, 'content_001', '003', 0, 2)
_main_call(1, 'content_001', '003', 0, 3)
_main_call(1, 'content_001', '003', 0, 4)

_main_call(1, 'content_001', '003', 1, 0)
_main_call(1, 'content_001', '003', 1, 1)
_main_call(1, 'content_001', '003', 1, 2)
_main_call(1, 'content_001', '003', 1, 3)
_main_call(1, 'content_001', '003', 1, 4)

_main_call(2, 'content_001', '003', 0, 0)
_main_call(2, 'content_001', '003', 0, 1)
_main_call(2, 'content_001', '003', 0, 2)
_main_call(2, 'content_001', '003', 0, 3)
_main_call(2, 'content_001', '003', 0, 4)

_main_call(2, 'content_001', '003', 1, 0)
_main_call(2, 'content_001', '003', 1, 1)
_main_call(2, 'content_001', '003', 1, 2)
_main_call(2, 'content_001', '003', 1, 3)
_main_call(2, 'content_001', '003', 1, 4)

_main_call(3, 'content_001', '003', 0, 0)
_main_call(3, 'content_001', '003', 0, 1)
_main_call(3, 'content_001', '003', 0, 2)
_main_call(3, 'content_001', '003', 0, 3)
_main_call(3, 'content_001', '003', 0, 4)

_main_call(3, 'content_001', '003', 1, 0)
_main_call(3, 'content_001', '003', 1, 1)
_main_call(3, 'content_001', '003', 1, 2)
_main_call(3, 'content_001', '003', 1, 3)
_main_call(3, 'content_001', '003', 1, 4)

# %% [markdown]
# ## content_002

# %% [markdown]
# ### style_001.jpeg

# %%
_main_call(1, 'content_002', '001', 0, 0)
_main_call(1, 'content_002', '001', 0, 1)
_main_call(1, 'content_002', '001', 0, 2)
_main_call(1, 'content_002', '001', 0, 3)
_main_call(1, 'content_002', '001', 0, 4)

_main_call(1, 'content_002', '001', 1, 0)
_main_call(1, 'content_002', '001', 1, 1)
_main_call(1, 'content_002', '001', 1, 2)
_main_call(1, 'content_002', '001', 1, 3)
_main_call(1, 'content_002', '001', 1, 4)

_main_call(2, 'content_002', '001', 0, 0)
_main_call(2, 'content_002', '001', 0, 1)
_main_call(2, 'content_002', '001', 0, 2)
_main_call(2, 'content_002', '001', 0, 3)
_main_call(2, 'content_002', '001', 0, 4)

_main_call(2, 'content_002', '001', 1, 0)
_main_call(2, 'content_002', '001', 1, 1)
_main_call(2, 'content_002', '001', 1, 2)
_main_call(2, 'content_002', '001', 1, 3)
_main_call(2, 'content_002', '001', 1, 4)

_main_call(3, 'content_002', '001', 0, 0)
_main_call(3, 'content_002', '001', 0, 1)
_main_call(3, 'content_002', '001', 0, 2)
_main_call(3, 'content_002', '001', 0, 3)
_main_call(3, 'content_002', '001', 0, 4)

_main_call(3, 'content_002', '001', 1, 0)
_main_call(3, 'content_002', '001', 1, 1)
_main_call(3, 'content_002', '001', 1, 2)
_main_call(3, 'content_002', '001', 1, 3)
_main_call(3, 'content_002', '001', 1, 4)

# %% [markdown]
# ### style_002.jpeg

# %%
_main_call(1, 'content_002', '002', 0, 0)
_main_call(1, 'content_002', '002', 0, 1)
_main_call(1, 'content_002', '002', 0, 2)
_main_call(1, 'content_002', '002', 0, 3)
_main_call(1, 'content_002', '002', 0, 4)

_main_call(1, 'content_002', '002', 1, 0)
_main_call(1, 'content_002', '002', 1, 1)
_main_call(1, 'content_002', '002', 1, 2)
_main_call(1, 'content_002', '002', 1, 3)
_main_call(1, 'content_002', '002', 1, 4)

_main_call(2, 'content_002', '002', 0, 0)
_main_call(2, 'content_002', '002', 0, 1)
_main_call(2, 'content_002', '002', 0, 2)
_main_call(2, 'content_002', '002', 0, 3)
_main_call(2, 'content_002', '002', 0, 4)

_main_call(2, 'content_002', '002', 1, 0)
_main_call(2, 'content_002', '002', 1, 1)
_main_call(2, 'content_002', '002', 1, 2)
_main_call(2, 'content_002', '002', 1, 3)
_main_call(2, 'content_002', '002', 1, 4)

_main_call(3, 'content_002', '002', 0, 0)
_main_call(3, 'content_002', '002', 0, 1)
_main_call(3, 'content_002', '002', 0, 2)
_main_call(3, 'content_002', '002', 0, 3)
_main_call(3, 'content_002', '002', 0, 4)

_main_call(3, 'content_002', '002', 1, 0)
_main_call(3, 'content_002', '002', 1, 1)
_main_call(3, 'content_002', '002', 1, 2)
_main_call(3, 'content_002', '002', 1, 3)
_main_call(3, 'content_002', '002', 1, 4)

# %% [markdown]
# ### style_003.jpeg

# %%
_main_call(1, 'content_002', '003', 0, 0)
_main_call(1, 'content_002', '003', 0, 1)
_main_call(1, 'content_002', '003', 0, 2)
_main_call(1, 'content_002', '003', 0, 3)
_main_call(1, 'content_002', '003', 0, 4)

_main_call(1, 'content_002', '003', 1, 0)
_main_call(1, 'content_002', '003', 1, 1)
_main_call(1, 'content_002', '003', 1, 2)
_main_call(1, 'content_002', '003', 1, 3)
_main_call(1, 'content_002', '003', 1, 4)

_main_call(2, 'content_002', '003', 0, 0)
_main_call(2, 'content_002', '003', 0, 1)
_main_call(2, 'content_002', '003', 0, 2)
_main_call(2, 'content_002', '003', 0, 3)
_main_call(2, 'content_002', '003', 0, 4)

_main_call(2, 'content_002', '003', 1, 0)
_main_call(2, 'content_002', '003', 1, 1)
_main_call(2, 'content_002', '003', 1, 2)
_main_call(2, 'content_002', '003', 1, 3)
_main_call(2, 'content_002', '003', 1, 4)

_main_call(3, 'content_002', '003', 0, 0)
_main_call(3, 'content_002', '003', 0, 1)
_main_call(3, 'content_002', '003', 0, 2)
_main_call(3, 'content_002', '003', 0, 3)
_main_call(3, 'content_002', '003', 0, 4)

_main_call(3, 'content_002', '003', 1, 0)
_main_call(3, 'content_002', '003', 1, 1)
_main_call(3, 'content_002', '003', 1, 2)
_main_call(3, 'content_002', '003', 1, 3)
_main_call(3, 'content_002', '003', 1, 4)
